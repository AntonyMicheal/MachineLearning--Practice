# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.linspace(0,10,20)

# %%
x
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
y = x * x
z = x + y

# %%
y
# Out:
# array([  0.        ,   0.27700831,   1.10803324,   2.49307479,
#          4.43213296,   6.92520776,   9.97229917,  13.5734072 ,
#         17.72853186,  22.43767313,  27.70083102,  33.51800554,
#         39.88919668,  46.81440443,  54.29362881,  62.32686981,
#         70.91412742,  80.05540166,  89.75069252, 100.        ])

# %%
z
# Out:
# array([  0.        ,   0.8033241 ,   2.16066482,   4.07202216,
#          6.53739612,   9.5567867 ,  13.13019391,  17.25761773,
#         21.93905817,  27.17451524,  32.96398892,  39.30747922,
#         46.20498615,  53.6565097 ,  61.66204986,  70.22160665,
#         79.33518006,  89.00277008,  99.22437673, 110.        ])

# %%
# Creating plot using matplot lib.

plt.plot(x,y)
plt.xlabel('X-Axis') # labeling the x axis
plt.ylabel('Y-Axis') # labeling the y axis
plt.title('Un-necessary Plot') # labeling the title
# Out:
# Text(0.5, 1.0, 'Un-necessary Plot')

# %%
# Creating plot using matplot lib.

plt.plot(x, x)
plt.xlabel('X-Axis') # labeling the x axis
plt.ylabel('Y-Axis') # labeling the y axis
plt.title('Un-necessary Plot') # labeling the title
# Out:
# Text(0.5, 1.0, 'Un-necessary Plot')

# %%
# Creating plot using matplot lib.

plt.plot(x,y,x, x)
plt.xlabel('X-Axis') # labeling the x axis
plt.ylabel('Y-Axis') # labeling the y axis
plt.title('Un-necessary Plot') # labeling the title
# Out:
# Text(0.5, 1.0, 'Un-necessary Plot')

# %%
# the above graph looks like that is because x increments only till 10 and y value goes up to 100.

# %%
# Creating plot using matplot lib.

plt.plot(x,y,x, z, y, z)
plt.xlabel('X-Axis') # labeling the x axis
plt.ylabel('Y-Axis') # labeling the y axis
plt.title('Un-necessary Plot') # labeling the title
# Out:
# Text(0.5, 1.0, 'Un-necessary Plot')

# %% [markdown]
# ## Subplots

# %%
plt.subplot(3,2,1)
plt.plot(x,x)
plt.subplot(3,2,2)
plt.plot(x,y)

plt.subplot(3,2,5)
plt.plot(x,y, x,x)

plt.subplot(3,2,6)
plt.plot(x,z,y)
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>
